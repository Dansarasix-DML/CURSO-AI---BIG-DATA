# %% [markdown]
# Realizar los siguientes ejercicios.
#
# ---
#
# # Ejercicio 1: Regresion - Prediccion del precio del alquiler
#
# ### 🎯Objetivo:
# Predecir el precio del alquiler de viviendas en funcion de sus caracteristicas.
#
# ### 📘Dataset:
# Puedes usar el conjunto de datos 'california_housing' de Scikit-Learn.
#
# ### 🧠Tareas:
#
# 1. Carga los datos y escalalos.
# 2. Divide en conjunto de entrenamiento y prueba.
# 3. Construye una red neuronal:
#   - Entrada segun las caracteristicas.
#   - Capa oculta de 16 neuronas con ReLU.
#   - Capa oculta de 8 neuronas con ReLU.
#   - Capa de salida con 1 neurona y activacion lineal.
# 4. Compila con:
#   - Optimizer: Adam
#   - Loss: MSE
#   - Metricas: MAE
# 5. Entrena el modelo y visualiza la curva de perdida.

# %% [markdown]
# # Ejercicio 2: Clasificacion binaria - Cancer de mama
# ### 🎯Objetivo:
# Clasificar si un tumor es maligno o benigno.
#
# ### 📘Dataset:
# Usa el conjunto 'breast_cancer' de Scikit-Learn.
#
# ### 🧠Tareas:
# 1. Carga y estandariza los datos.
# 2. Crea un modelo:
#   - Capa oculta de 16 neuronas con ReLU.
#   - Capa de salida con 1 neurona y sigmoide.
# 3. Compila con:
#   - Loss: binary_crossentropy
#   - Metricas: accuracy
# 4. Entrena y evalua el modelo.
# 5. Muestra matriz de confusion, precision y recall.

# %% [markdown]
# # Ejercicio 3: Clasificacion multiclase - Digitos (MNIST)
# ### 🎯Objetivo:
# Reconocer digitos escritos a mano (0 al 9).
#
# ### 📘Dataset:
# MNIST (keras.datasets.mnist)
#
# ### 🧠Tareas:
# 1. Carga y normaliza los datos.
# 2. Convierte etiquetas a one-hot.
# 3. Modelo:
#   - Flatten
#   - Dense(128, ReLU)
#   - Dense(10, softmax)
# 4. Compila con:
#   - Loss: categorical_crossentropy
#   - Metricas: accuracy
# 5. Entrena y evalua el modelo.
# 6. Visualiza algunas predicciones.
